# %%
from autogluon.tabular import TabularDataset, TabularPredictor
predictor = TabularPredictor.load('C:\\code\\EL\\output')
student_models = predictor.distill(time_limit=60*5)

print(student_models)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from autogluon.tabular import TabularDataset, TabularPredictor
#       2 predictor = TabularPredictor.load('C:\\code\\EL\\output')
# ----> 3 student_models = predictor.distill(time_limit=60*5)
#       5 print(student_models)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\autogluon\tabular\predictor\predictor.py:4460, in TabularPredictor.distill(self, train_data, tuning_data, augmentation_data, time_limit, hyperparameters, holdout_frac, teacher_preds, augment_method, augment_args, models_name_suffix, verbosity)
#    4458 if isinstance(hyperparameters, str):
#    4459     hyperparameters = get_hyperparameter_config(hyperparameters)
# -> 4460 return self._learner.distill(
#    4461     X=train_data,
#    4462     X_val=tuning_data,
#    4463     time_limit=time_limit,
# ...
